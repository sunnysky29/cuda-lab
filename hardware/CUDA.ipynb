# %% [markdown]
# ## thread，block，grid

# %% [markdown]
# 每个Thread都会执行我们所定义的kernel函数
#
# ![image.png](attachment:image.png)
#
# 理论上，每个Grid是三维的Block所组成，每个Block也是三维的Thread所组成（图8），因此最大可以在六个抽象维度上做并行:
#
# ![image-2.png](attachment:image-2.png)
